# %% [markdown]
# ## Importing libraries

# %%
# libraries to help with reading and manipulating data
import pandas as pd
import numpy as np

# libraries to help with data visualization
import matplotlib.pyplot as plt
import seaborn as sns

# libraries to get metrics
from sklearn import metrics

# to get different metric scores
from sklearn.metrics import (
    f1_score,
    accuracy_score,
    recall_score,
    precision_score,
    confusion_matrix,
    roc_auc_score,
    plot_confusion_matrix,
)

# to split the data
from sklearn.model_selection import train_test_split, StratifiedKFold, cross_val_score

# to be used for data scaling and one hot encoding
from sklearn.preprocessing import StandardScaler, MinMaxScaler, OneHotEncoder

# to impute missing values
from sklearn.impute import SimpleImputer

# to oversample and undersample data
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler

# to do hyperparameter tuning
from sklearn.model_selection import RandomizedSearchCV

# to be used for creating pipelines and personalizing them
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

# to define maximum number of columns displayed in a dataframe
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows',None)

# to suppress scientific notations for a dataframe
pd.set_option("display.float_format", lambda x: "%.3f" % x)

# to help with model building
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import(
     AdaBoostClassifier,
     GradientBoostingClassifier,
     RandomForestClassifier,
     BaggingClassifier,
)


# to suppress warnings
import warnings

warnings.filterwarnings("ignore")

# %%
from xgboost import XGBClassifier

# to suppress scientific notations for a dataframe
pd.set_option("display.float_format", lambda x: "%.3f" % x)

# %% [markdown]
# ## Loading Data

# %%
# to read the training data
df = pd.read_csv("Train.csv.csv")

# %%
# to read the test data
df1 = pd.read_csv("Test.csv.csv")

# %%
# to check the number of rows and columns in the training data
df.shape
# Out:
# (20000, 41)

# %% [markdown]
# #### Observation:
# * There are 20000 rows and 41 columns in the training data

# %%
# to check the number of rows and columns in the test data
df1.shape
# Out:
# (5000, 41)

# %% [markdown]
# #### Observation:
# * There are 5000 rows and 41 columns in the test data

# %% [markdown]
# ## Data Overview

# %%
# to create a copy of the training data
data = df.copy()

# %%
# to create a copy of the test data
data_test = df1.copy()

# %%
# to display the first 5 rows of the training data
data.head()
# Out:
#       V1     V2     V3     V4     V5     V6     V7     V8     V9    V10  \
# 0 -4.465 -4.679  3.102  0.506 -0.221 -2.033 -2.911  0.051 -1.522  3.762
# 1  3.366  3.653  0.910 -1.368  0.332  2.359  0.733 -4.332  0.566 -0.101
# 2 -3.832 -5.824  0.634 -2.419 -1.774  1.017 -2.099 -3.173 -2.082  5.393
# 3  1.618  1.888  7.046 -1.147  0.083 -1.530  0.207 -2.494  0.345  2.119
# 4 -0.111  3.872 -3.758 -2.983  3.793  0.545  0.205  4.849 -1.855 -6.220
#
#      V11    V12    V13    V14    V15    V16    V17    V18    V19    V20  \
# 0 -5.715  0.736  0.981  1.418 -3.376 -3.047  0.306  2.914  2.270  4.395
# 1  1.914 -0.951 -1.255 -2.707  0.193 -4.769 -2.205  0.908  0.757 -5.834
# 2 -0.771  1.107  1.144  0.943 -3.164 -4.248 -4.039  3.689  3.311  1.059
# 3 -3.053  0.460  2.705 -0.636 -0.454 -3.174 -3.404 -1.282  1.582 -1.952
# 4  1.998  4.724  0.709 -1.989 -2.633  4.184  2.245  3.734 -6.313 -5.380
#
#      V21    V22    V23    V24    V25    V26    V27    V28    V29    V30  \
# ...

# %%
# to display the last 5 rows of the train data
data.tail()
# Out:
#           V1      V2     V3     V4     V5     V6     V7     V8     V9    V10  \
# 19995 -2.071  -1.088 -0.796 -3.012 -2.288  2.807  0.481  0.105 -0.587 -2.899
# 19996  2.890   2.483  5.644  0.937 -1.381  0.412 -1.593 -5.762  2.150  0.272
# 19997 -3.897  -3.942 -0.351 -2.417  1.108 -1.528 -3.520  2.055 -0.234 -0.358
# 19998 -3.187 -10.052  5.696 -4.370 -5.355 -1.873 -3.947  0.679 -2.389  5.457
# 19999 -2.687   1.961  6.137  2.600  2.657 -4.291 -2.344  0.974 -1.027  0.497
#
#          V11    V12   V13    V14    V15     V16    V17    V18    V19    V20  \
# 19995  8.868  1.717 1.358 -1.777  0.710   4.945 -3.100 -1.199 -1.085 -0.365
# 19996 -2.095 -1.526 0.072 -3.540 -2.762 -10.632 -0.495  1.720  3.872 -1.210
# 19997 -3.782  2.180 6.112  1.985 -8.330  -1.639 -0.915  5.672 -3.924  2.133
# 19998  1.583  3.571 9.227  2.554 -7.039  -0.994 -9.665  1.155  3.877  3.524
# 19999 -9.589  3.177 1.055 -1.416 -4.669  -5.405  3.720  2.893  2.329  1.458
#
# ...

# %%
# to check the data types of columns in the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 41 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   V1      19982 non-null  float64
#  1   V2      19982 non-null  float64
#  2   V3      20000 non-null  float64
#  3   V4      20000 non-null  float64
#  4   V5      20000 non-null  float64
#  5   V6      20000 non-null  float64
#  6   V7      20000 non-null  float64
#  7   V8      20000 non-null  float64
#  8   V9      20000 non-null  float64
#  9   V10     20000 non-null  float64
#  10  V11     20000 non-null  float64
#  11  V12     20000 non-null  float64
#  12  V13     20000 non-null  float64
#  13  V14     20000 non-null  float64
#  14  V15     20000 non-null  float64
#  15  V16     20000 non-null  float64
#  16  V17     20000 non-null  float64
#  17  V18     20000 non-null  float64
#  18  V19     20000 non-null  float64
#  19  V20     20000 non-null  float64
# ...

# %% [markdown]
# #### Observation:
# * It can be observed that there are missing values in columns V1 and V2.
#
# * The datatypes of all columns are of the float64 datatype.
#
# * The memory usage is about 6.3 megabytes

# %%
# to check for duplicate values in the training data
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### Observation:
# * There are no duplicates in the training data.

# %%
# to check for missing values
data.isnull().any()
# Out:
# V1         True
# V2         True
# V3        False
# V4        False
# V5        False
# V6        False
# V7        False
# V8        False
# V9        False
# V10       False
# V11       False
# V12       False
# V13       False
# V14       False
# V15       False
# V16       False
# V17       False
# V18       False
# V19       False
# V20       False
# V21       False
# V22       False
# V23       False
# V24       False
# V25       False
# V26       False
# V27       False
# V28       False
# V29       False
# V30       False
# V31       False
# V32       False
# V33       False
# V34       False
# V35       False
# V36       False
# V37       False
# V38       False
# V39       False
# V40       False
# Target    False
# dtype: bool

# %% [markdown]
# #### Observation:
# * The columns V1 and V2 have missing valuesin the training data.

# %%
# to check the missing values in the test data
data_test.isnull().any()
# Out:
# V1         True
# V2         True
# V3        False
# V4        False
# V5        False
# V6        False
# V7        False
# V8        False
# V9        False
# V10       False
# V11       False
# V12       False
# V13       False
# V14       False
# V15       False
# V16       False
# V17       False
# V18       False
# V19       False
# V20       False
# V21       False
# V22       False
# V23       False
# V24       False
# V25       False
# V26       False
# V27       False
# V28       False
# V29       False
# V30       False
# V31       False
# V32       False
# V33       False
# V34       False
# V35       False
# V36       False
# V37       False
# V38       False
# V39       False
# V40       False
# Target    False
# dtype: bool

# %% [markdown]
# #### Observation:
# * Columns V1 and V2 have missing values in the test data

# %%
# to check the statistical summary of the training data
data.describe(include='number').T
# Out:
#            count   mean   std     min    25%    50%    75%    max
# V1     19982.000 -0.272 3.442 -11.876 -2.737 -0.748  1.840 15.493
# V2     19982.000  0.440 3.151 -12.320 -1.641  0.472  2.544 13.089
# V3     20000.000  2.485 3.389 -10.708  0.207  2.256  4.566 17.091
# V4     20000.000 -0.083 3.432 -15.082 -2.348 -0.135  2.131 13.236
# V5     20000.000 -0.054 2.105  -8.603 -1.536 -0.102  1.340  8.134
# V6     20000.000 -0.995 2.041 -10.227 -2.347 -1.001  0.380  6.976
# V7     20000.000 -0.879 1.762  -7.950 -2.031 -0.917  0.224  8.006
# V8     20000.000 -0.548 3.296 -15.658 -2.643 -0.389  1.723 11.679
# V9     20000.000 -0.017 2.161  -8.596 -1.495 -0.068  1.409  8.138
# V10    20000.000 -0.013 2.193  -9.854 -1.411  0.101  1.477  8.108
# V11    20000.000 -1.895 3.124 -14.832 -3.922 -1.921  0.119 11.826
# V12    20000.000  1.605 2.930 -12.948 -0.397  1.508  3.571 15.081
# V13    20000.000  1.580 2.875 -13.228 -0.224  1.637  3.460 15.420
# ...

# %% [markdown]
# #### Observation:
# * The mean of the ciphered values contains some negative values.
#
# * The standard deviation of the ciphered values are all of postive values.
#
# * The ciphered values of V1 and V2 are missing 18 values each
#
# * The minimum ciphered values among the columns is -20.374 from the sensor V16.
#
# * The maximum ciphered values among the columns is 23.6331865 from the sensor V32.

# %% [markdown]
# ## EDA

# %% [markdown]
# ### Univariate Analysis

# %% [markdown]
# ### Plotting histograms and boxplots for all the variables

# %%
# function to plot a boxplot and a histogram along the same scale.


def histogram_boxplot(data, feature, figsize=(12, 7), kde=False, bins=None):
    """
    Boxplot and histogram combined

    data: dataframe
    feature: dataframe column
    figsize: size of figure (default (12,7))
    kde: whether to the show density curve (default False)
    bins: number of bins for histogram (default None)
    """
    f2, (ax_box2, ax_hist2) = plt.subplots(
        nrows=2,  # Number of rows of the subplot grid= 2
        sharex=True,  # x-axis will be shared among all subplots
        gridspec_kw={"height_ratios": (0.25, 0.75)},
        figsize=figsize,
    )  # creating the 2 subplots
    sns.boxplot(
        data=data, x=feature, ax=ax_box2, showmeans=True, color="violet"
    )  # boxplot will be created and a star will indicate the mean value of the column
    sns.histplot(
        data=data, x=feature, kde=kde, ax=ax_hist2, bins=bins, palette="winter"
    ) if bins else sns.histplot(
        data=data, x=feature, kde=kde, ax=ax_hist2
    )  # For histogram
    ax_hist2.axvline(
        data[feature].mean(), color="green", linestyle="--"
    )  # Add mean to the histogram
    ax_hist2.axvline(
        data[feature].median(), color="black", linestyle="-"
    )  # Add median to the histogram

# %% [markdown]
# ### Plotting all the features at one go

# %%
## Please change the dataframe name as you define while reading the data
for feature in df.columns:
    histogram_boxplot(df, feature, figsize=(12, 7), kde=False, bins=None)

# %% [markdown]
# #### Observation:
#
# * All the variables are considered as a normal distrbution.
#
# * There are also presence of outliers in the columns.
#
# * The outliers will not be treated due to the sensitive information each sensor provide.
#
# * The target variable is either 0 or 1.

# %% [markdown]
# ###  Values check in target variable

# %%
# to check the value counts of the target variable in the training set
data.Target.value_counts(normalize=True)
# Out:
# 0   0.945
# 1   0.056
# Name: Target, dtype: float64

# %% [markdown]
# #### Observation:
#
# * The target variable is inbalanced. We could use oversampling techniques to balance the data.
#
# * Over 94% of the target are non failures while less than 5% of the data are failures.

# %%
# to check the value of the target variable in the test set
data_test.Target.value_counts(normalize=True)
# Out:
# 0   0.944
# 1   0.056
# Name: Target, dtype: float64

# %% [markdown]
# #### Observation:
# * The target variable is inbalanced. We could use oversampling techniques to balance the test data.
#
# * Over 94% of the target are non failures while less than 5% of the data are failures.

# %% [markdown]
# ## Data Pre-processing
#
# * Data pre processing is done to create variables to store dependent and independent variables.
#
# * The training data is also split into train set and validation for building the model.
#
# * The training data has missing values but the data is preprocessed first in order to prevent data leakage.

# %%
# to split the training data 
X = data.drop(["Target"], axis=1)
y = data["Target"]

# %%
# to split the test data
X_test = data_test.drop(["Target"], axis=1)
y_test = data_test["Target"]

# %%
# Splitting data into training and validation set:

X_train, X_val, y_train, y_val = train_test_split(X, y, test_size = 0.25, random_state = 1, stratify=y) 

print(X_train.shape, X_val.shape, X_test.shape)
# Out:
# (15000, 40) (5000, 40) (5000, 40)

# %% [markdown]
# #### Observation:
#
# * The training data is splitted into two sets, training and validation set.
#
# * This section helps to prevent data leakage. After splitting the data, we can perform any imputation into the data like treating missing values.

# %% [markdown]
# ### Missing values treatment

# %%
# to create an instance of the imputer

imputer = SimpleImputer(strategy="median")

# %% [markdown]
# #### Observation:
#
# * The median is used as the imputer for missing values because the EDA shows that all the columns are of a normal distribution.
#
# * The imputation of the median of the columns will help maintain a normal distribution.

# %%
# to fit and transform the training data

X_train = pd.DataFrame(imputer.fit_transform(X_train), columns = X_train.columns)

# %%
# to fit and transform the validation data

X_val = pd.DataFrame(imputer.fit_transform(X_val), columns = X_val.columns)

# %%
# to fit and tranasform the test data

X_test = pd.DataFrame(imputer.fit_transform(X_test), columns = X_test.columns)

# %%
# to check if there are still missing values

print(X_train.isnull().sum())
print("-" * 30)

# to check the count of null values in the validation set
print(X_val.isnull().sum())
print("-" * 30)

# tocheck the count of null values in the test set
X_test.isnull().sum()
# Out:
# V1     0
# V2     0
# V3     0
# V4     0
# V5     0
# V6     0
# V7     0
# V8     0
# V9     0
# V10    0
# V11    0
# V12    0
# V13    0
# V14    0
# V15    0
# V16    0
# V17    0
# V18    0
# V19    0
# V20    0
# V21    0
# V22    0
# V23    0
# V24    0
# V25    0
# V26    0
# V27    0
# V28    0
# V29    0
# V30    0
# V31    0
# V32    0
# V33    0
# V34    0
# V35    0
# V36    0
# V37    0
# V38    0
# V39    0
# V40    0
# dtype: int64
# ------------------------------
# V1     0
# V2     0
# V3     0
# V4     0
# V5     0
# V6     0
# V7     0
# V8     0
# V9     0
# V10    0
# V11    0
# V12    0
# V13    0
# V14    0
# V15    0
# V16    0
# V17    0
# V18    0
# V19    0
# V20    0
# V21    0
# V22    0
# V23    0
# V24    0
# V25    0
# V26    0
# V27    0
# V28    0
# V29    0
# V30    0
# V31    0
# V32    0
# V33    0
# V34    0
# V35    0
# V36    0
# V37    0
# V38    0
# V39    0
# V40    0
# dtype: int64
# ------------------------------
# V1     0
# V2     0
# ...

# %% [markdown]
# #### Observation:
# * There are no missing values in the training, validation and test data.
#
# * Columns V1 and V2 have been replace with the medians of their respective columns.

# %% [markdown]
# ## Model Building

# %% [markdown]
# ### Model evaluation criterion
#
# The nature of predictions made by the classification model will translate as follows:
#
# - True positives (TP) are failures correctly predicted by the model.
# - False negatives (FN) are real failures in a generator where there is no detection by model.
# - False positives (FP) are failure detections in a generator where there is no failure.
#
# ### Which metric to optimize?
#
# * We need to choose the metric which will ensure that the maximum number of generator failures are predicted correctly by the model.
# * We would want Recall to be maximized as greater the Recall, the higher the chances of minimizing false negatives.
# * We want to minimize false negatives because if a model predicts that a machine will have no failure when there will be a failure, it will increase the maintenance cost.

# %% [markdown]
# **Let's define a function to output different metrics (including recall) on the train and test set and a function to show confusion matrix so that we do not have to use the same code repetitively while evaluating models.**

# %%
# defining a function to compute different metrics to check performance of a classification model built using sklearn
def model_performance_classification_sklearn(model, predictors, target):
    """
    Function to compute different metrics to check classification model performance

    model: classifier
    predictors: independent variables
    target: dependent variable
    """

    # predicting using the independent variables
    pred = model.predict(predictors)

    acc = accuracy_score(target, pred)  # to compute Accuracy
    recall = recall_score(target, pred)  # to compute Recall
    precision = precision_score(target, pred)  # to compute Precision
    f1 = f1_score(target, pred)  # to compute F1-score

    # creating a dataframe of metrics
    df_perf = pd.DataFrame(
        {
            "Accuracy": acc,
            "Recall": recall,
            "Precision": precision,
            "F1": f1
            
        },
        index=[0],
    )

    return df_perf

# %%
def confusion_matrix_sklearn(model, predictors, target):
    """
    To plot the confusion_matrix with percentages

    model: classifier
    predictors: independent variables
    target: dependent variable
    """
    y_pred = model.predict(predictors)
    cm = confusion_matrix(target, y_pred)
    labels = np.asarray(
        [
            ["{0:0.0f}".format(item) + "\n{0:.2%}".format(item / cm.flatten().sum())]
            for item in cm.flatten()
        ]
    ).reshape(2, 2)

    plt.figure(figsize=(6, 4))
    sns.heatmap(cm, annot=labels, fmt="")
    plt.ylabel("True label")
    plt.xlabel("Predicted label")

# %% [markdown]
# ### Defining scorer to be used for cross-validation and hyperparameter tuning
#
# - We want to reduce false negatives and will try to maximize "Recall".
# - To maximize Recall, we can use Recall as a **scorer** in cross-validation and hyperparameter tuning.

# %%
# Type of scoring used to compare parameter combinations
scorer = metrics.make_scorer(metrics.recall_score)

# %% [markdown]
# ### Model Building with original data

# %% [markdown]
# Sample Decision Tree model, Logistic Regression Model, RandomForest Model, Bagging Classifier Model, AdaBoost Classifier Model, Gradient Boosting Model and XGB Classifier Model building with original data.

# %%
models = []  # Empty list to store all the models

# Appending models into the list
models.append(("logistic", LogisticRegression(random_state=1)))

models.append(("dtree", DecisionTreeClassifier(random_state=1)))

models.append(("RF", RandomForestClassifier(random_state = 1)))

models.append(("Bagging", BaggingClassifier(random_state = 1)))

models.append(("Ada", AdaBoostClassifier(random_state = 1)))


models.append(("Grad", GradientBoostingClassifier(random_state = 1)))

models.append(("XGB", XGBClassifier(random_state = 1,eval_metric="logloss")))

results1 = []  # Empty list to store all model's CV scores
names = []  # Empty list to store name of the models


# loop through all models to get the mean cross validated score
print("\n" "Cross-Validation Score:" "\n")

for name, model in models:
    kfold = StratifiedKFold(
        n_splits=5, shuffle=True, random_state=1
    )  # Setting number of splits equal to 5
    cv_result = cross_val_score(
        estimator=model, X=X_train, y=y_train, scoring=scorer, cv=kfold
    )
    results1.append(cv_result)
    names.append(name)
    print("{}: {}".format(name, cv_result.mean()))

print("\n" "Validation Performance:" "\n")

for name, model in models:
    model.fit(X_train, y_train)
    scores = recall_score(y_val, model.predict(X_val))
    print("{}: {}".format(name, scores))
# Out:
# Cross-Validation Score:
#
# logistic: 0.4927566553639709
# dtree: 0.6982829521679532
# RF: 0.7235192266070268
# Bagging: 0.7210807301060529
# Ada: 0.6309140754635308
# Grad: 0.7066661857008874
# XGB: 0.7956208065796118
#
# Validation Performance:
#
# logistic: 0.48201438848920863
# dtree: 0.7050359712230215
# RF: 0.7266187050359713
# Bagging: 0.7302158273381295
# Ada: 0.6762589928057554
# Grad: 0.7230215827338129
# XGB: 0.8201438848920863

# %% [markdown]
# #### Observation:
#
# * The average Cost validation score across RandomForest, Bagging Classifer and XGBoost Classfier are above 70%.
#
# * Random Forest, Bagging Classifier, Gradient Boosting and XGboost Classifier generalised well on the validation set.
#
# * Let's tune this models if they can perform better.
#
# - The Performance of Bagging and XGBoost is highest on cross-validation for the original data where the target variable is inbalanced

# %%
# Plotting boxplots for CV scores of all models defined above
fig = plt.figure(figsize=(10, 7))

fig.suptitle("Algorithm Comparison")
ax = fig.add_subplot(111)

plt.boxplot(results1)
ax.set_xticklabels(names)

plt.show()

# %% [markdown]
# #### Observation:
#
# * From the above plot, the logistic regression model has the lowest cross validation score, while the XGBoost CLassifier has the highest cross validation score among all other models.
#
# - The boxplot shows that the performance of bagging is consistent with 1 outlier.

# %%
print("\n" "Confusion matrix for all models" "\n")

for name, model in models:

    confusion_matrix_sklearn(model, X_val, y_val)
    plt.title(name)
# Out:
# Confusion matrix for all models

# %% [markdown]
# #### Observation:
#
# * The False Negatives of the XGBoost model is low at 1% (50), the false positives also is low (0.12%).
#
# * The XGBoost model is performing well on the validation set.

# %% [markdown]
# ### Model Building with Oversampled data

# %% [markdown]
# - Let's apply a sampling technique to deal with the imbalanced data in the target variable.

# %% [markdown]
# #### Apply SMOTE to create synthetic data on minority data

# %%
# Synthetic Minority Over Sampling Technique
sm = SMOTE(sampling_strategy=1, k_neighbors=5, random_state=1)

X_train_over, y_train_over = sm.fit_resample(X_train, y_train)

# %%
print("Before OverSampling, counts of label '1': {}".format(sum(y_train == 1)))
print("Before OverSampling, counts of label '0': {} \n".format(sum(y_train == 0)))
# Out:
# Before OverSampling, counts of label '1': 832
# Before OverSampling, counts of label '0': 14168

# %%
print("After OverSampling, counts of label '1': {}".format(sum(y_train_over == 1)))
print("After OverSampling, counts of label '0': {} \n".format(sum(y_train_over == 0)))
# Out:
# After OverSampling, counts of label '1': 14168
# After OverSampling, counts of label '0': 14168

# %%
print("After OverSampling, the shape of X_train: {}".format(X_train_over.shape))
print("After OverSampling, the shape of y_train: {} \n".format(y_train_over.shape))
# Out:
# After OverSampling, the shape of X_train: (28336, 40)
# After OverSampling, the shape of y_train: (28336,)

# %% [markdown]
# #### Build models with oversampled data

# %%
modell = []  # Empty list to store all the models
# Appending models into the list
modell.append(("logistic", LogisticRegression(random_state=1)))

modell.append(("dtree", DecisionTreeClassifier(random_state=1)))

modell.append(("Bagging", BaggingClassifier(random_state = 1)))

modell.append(("RF", RandomForestClassifier(random_state = 1)))

modell.append(("Ada", AdaBoostClassifier(random_state = 1)))

modell.append(("Grad", GradientBoostingClassifier(random_state = 1)))

modell.append(("XGB", XGBClassifier(random_state = 1,eval_metric="logloss")))

results2=[]  # Empty list to store all model's CV scores
namess = []  # Empty list to store name of the models

# loop through all models to get the mean cross validated score
print("\n" "Cross-Validation Score:" "\n")

for name, model in modell:
    kfold = StratifiedKFold(
        n_splits=5, shuffle=True, random_state=1
    )  # Setting number of splits equal to 5
    cv_result = cross_val_score(
        estimator=model, X=X_train_over, y=y_train_over, scoring=scorer, cv=kfold
    )
    results2.append(cv_result)
    namess.append(name)
    print("{}: {}".format(name, cv_result.mean()))
    
    
print("\n" "Validation Performance:" "\n")

for name, model in modell:
    model.fit(X_train_over, y_train_over)
    scores = recall_score(y_val, model.predict(X_val))
    print("{}: {}".format(name, scores))
# Out:
# Cross-Validation Score:
#
# logistic: 0.883963699328486
# dtree: 0.9720494245534969
# Bagging: 0.9762141471581656
# RF: 0.9839075260047615
# Ada: 0.8978689011775473
# Grad: 0.9256068151319724
# XGB: 0.989554053559209
#
# Validation Performance:
#
# logistic: 0.8489208633093526
# dtree: 0.7769784172661871
# Bagging: 0.8345323741007195
# RF: 0.8489208633093526
# Ada: 0.8561151079136691
# Grad: 0.8776978417266187
# XGB: 0.8669064748201439

# %% [markdown]
# #### Observation:
#
# * It can be noticed that all models had a high cross validation score when using the oversampled data compared to the original data.
#
# * The logistic regression, bagging classifier, Random Forest, AdaBoost Classifier, Gradient Boost Classifier and XGBoost Classifier all performed well on the validation set.
#
# * XGBoost, Gradient Boost and AdaBoost models will be tuned and applied on the oversampled data.
#
# * The models listed above will be tuned with the oversampled data to try and improve the recall score.

# %%
# Plotting boxplots for CV scores of all models defined above
fig = plt.figure(figsize=(10, 7))

fig.suptitle("Algorithm Comparison")
ax = fig.add_subplot(111)

plt.boxplot(results2)
ax.set_xticklabels(namess)

plt.show()

# %% [markdown]
# #### Observation:
#
# * From the above plot, rhe logistic regression, AdaBoost Classifier and GradientBoost Classifier had the lowest recall scores.
#
# * The XGBoost Classifier, RandomForest Classifier, Decision Tree and Bagging Classifier had the highest cross validation scores.

# %%
print("\n" "Confusion matrix for all models" "\n")

for name, model in modell:

    confusion_matrix_sklearn(model, X_val, y_val)
    plt.title(name)
# Out:
# Confusion matrix for all models

# %% [markdown]
# #### Observation:
#
# * From the confusion matrix, the XGBoost model gives a well balanced trade-off between recall and precision.
#
# * Random Forest and Bagging models also produced good perfomance on the validation set.

# %% [markdown]
# ### Model Building with Undersampled data

# %% [markdown]
# - Let's apply a sampling technique to deal with the imbalanced data in the target variable.
#
# - An undersampling technique, RandomUnderSampler is used on the majority. This technique will reduce a lot of data points in the data and there is loss of important information.

# %% [markdown]
# #### Undersampling using the Random undersampler on the majority data

# %%
# Random undersampler for under sampling the data
rus = RandomUnderSampler(random_state=1, sampling_strategy=1)

X_train_un, y_train_un = rus.fit_resample(X_train, y_train)

# %%
print("Before UnderSampling, counts of label '1': {}".format(sum(y_train == 1)))
print("Before UnderSampling, counts of label '0': {} \n".format(sum(y_train == 0)))
# Out:
# Before UnderSampling, counts of label '1': 832
# Before UnderSampling, counts of label '0': 14168

# %%
print("After UnderSampling, counts of label '1': {}".format(sum(y_train_un == 1)))
print("After UnderSampling, counts of label '0': {} \n".format(sum(y_train_un == 0)))
# Out:
# After UnderSampling, counts of label '1': 832
# After UnderSampling, counts of label '0': 832

# %%
print("After UnderSampling, the shape of train_X : {}".format(X_train_un.shape))
print("After UnderSampling, the shape of train_y : {} \n".format(y_train_un.shape))
# Out:
# After UnderSampling, the shape of train_X : (1664, 40)
# After UnderSampling, the shape of train_y : (1664,)

# %%
un_model = []  # Empty list to store all the models
# Appending models into the list
un_model.append(("logistic", LogisticRegression(random_state=1)))

un_model.append(("dtree", DecisionTreeClassifier(random_state=1)))

un_model.append(("Bagging", BaggingClassifier(random_state = 1)))

un_model.append(("RA", RandomForestClassifier(random_state = 1)))

un_model.append(("Ada", AdaBoostClassifier(random_state = 1)))

un_model.append(("Grad", GradientBoostingClassifier(random_state = 1)))

un_model.append(("XGB", XGBClassifier(random_state = 1,eval_metric="logloss")))

un_results=[]  # Empty list to store all model's CV scores
names_un = []  # Empty list to store name of the models

# loop through all models to get the mean cross validated score
print("\n" "Cross-Validation Cost:" "\n")

for name, model in un_model:
    kfold = StratifiedKFold(
        n_splits=5, shuffle=True, random_state=1
    )  # Setting number of splits equal to 5
    
    cv_result_un = cross_val_score(
        estimator=model, X=X_train_over, y=y_train_over, scoring=scorer, cv=kfold
    )
    un_results.append(cv_result_un)
    names_un.append(name)
    print("{}: {}".format(name, cv_result_un.mean()))
    
    
print("\n" "Validation Performance:" "\n")

for name, model in un_model:
    model.fit(X_train_un, y_train_un)
    scores_un = recall_score(y_val, model.predict(X_val))
    print("{}: {}".format(name, scores_un))
# Out:
# Cross-Validation Cost:
#
# logistic: 0.883963699328486
# dtree: 0.9720494245534969
# Bagging: 0.9762141471581656
# RA: 0.9839075260047615
# Ada: 0.8978689011775473
# Grad: 0.9256068151319724
# XGB: 0.989554053559209
#
# Validation Performance:
#
# logistic: 0.8525179856115108
# dtree: 0.841726618705036
# Bagging: 0.8705035971223022
# RA: 0.8920863309352518
# Ada: 0.8489208633093526
# Grad: 0.8884892086330936
# XGB: 0.9028776978417267

# %% [markdown]
# #### Observation:
#
# * All models has a high cross validation score, XGBoost Classifier is the highest.
#
# * All models has a high recall score on the validation set.

# %%
# Plotting boxplots for CV scores of all models defined above
fig = plt.figure(figsize=(15, 10))

fig.suptitle("Algorithm Comparison")
ax = fig.add_subplot(111)

plt.boxplot(un_results)
ax.set_xticklabels(names_un)

plt.show()

# %% [markdown]
# #### Observation:
#
# * The Decision tree, Bagging Classifier, RandomForest Classifier and XGBoost Classifier has a high cross validation score.

# %%
print("\n" "Confusion matrix for all models" "\n")

for name, model in un_model:

    confusion_matrix_sklearn(model, X_val, y_val)
    plt.title(name)
# Out:
# Confusion matrix for all models

# %% [markdown]
# #### Observation:
#
# * The XGBoost model gives the best recall on the validation set, 0.44% False Negatives.
#
# * The RandomForest model also gives a good recall on the validation set. (0.30%) False Negatives
#
# * The Gradient Boost model also gives a good recall on the validation set.(0.62%) False Negatives.
#
# * The Random Forest and XGBoost will be tuned to search for better recall score.

# %% [markdown]
# ## HyperparameterTuning

# %% [markdown]
# #### There are some models that will be tuned with either the oversampled data or the undersampled data.
#
# */ DecisionTree Classifier with oversampled data will be a subject of hyperparameter tuning due to
# * The DecisionTree  model had a average cross validation score of 69% using recall core as the metric.
# * The DecisionTree model had a good recall score of 70% on the validation set.
#
# */ DecisionTree Classifier with undersampled data will be a subject of hyperparameter tuning due to
# * The DecisionTree CLassifier model had a average cross validation score of 97% using recall core as the metric.
# * The DecisionTree Classifier model had a good recall score of 84% on the validation set.
#
# */ RandomForest Classifier with oversampled data will be a subject of hyperparameter tuning due to
# * The RandomForest Classifier model had a average cross validation score of 97% using recall core as the metric.
# * The RandomForest Classifier model had a good recall score of 77% on the validation set.
#
# */ RandomForest Classifier with undersampled data will be a subject of hyperparameter tuning due to
# * The RandomForest Classifier model had a average cross validation score of 98% using recall core as the metric.
# * The RandomForest Classifier model had a good recall score of 89% on the validation set.
#
# */ AdaBoost Classifier with oversampled data will be a subject of hyperparameter tuning due to
# * The AdaBoost Classifier model had a average cross validation score of 89% using recall core as the metric.
# * The AdaBoost Classifier model had a good recall score of 84% on the validation set.
#
# */ GradientBoost Classifier with oversampled data will be a subject of hyperparameter tuning due to
# * The GradientBoost Classifier model had a average cross validation score of 92% using recall core as the metric.
# * The GradientBoost Classifier model had a good recall score of 87% on the validation set.
#
# */ XGBoost Classifier with oversampled data will be a subject of hyperparameter tuning due to
# * The XGBoost Classifier model had a average cross validation score of 98% using recall core as the metric.
# * The XGBoost Classifier model had a good recall score of 86% on the validation set.

# %% [markdown]
# ### Sample tuning method for Decision tree with original data

# %%
# %%time 

# defining model
Model = DecisionTreeClassifier(random_state=1)

# Parameter grid to pass in RandomSearchCV
param_grid = {'max_depth': np.arange(2,6),
              'min_samples_leaf': [1, 4, 7], 
              'max_leaf_nodes' : [10,15],
              'min_impurity_decrease': [0.0001,0.001] }

#Calling RandomizedSearchCV
randomized_cv = RandomizedSearchCV(estimator=Model, param_distributions=param_grid, n_iter=10, n_jobs = -1, scoring=scorer, cv=5, random_state=1)

#Fitting parameters in RandomizedSearchCV
randomized_cv.fit(X_train,y_train)

print("Best parameters are {} with CV score={}:" .format(randomized_cv.best_params_,randomized_cv.best_score_))
# Out:
# Best parameters are {'min_samples_leaf': 7, 'min_impurity_decrease': 0.0001, 'max_leaf_nodes': 15, 'max_depth': 5} with CV score=0.5684366207344347:
# Wall time: 18.4 s

# %% [markdown]
# #### Observation:
#
# * The Cross validation score for decision tree is about 56%
#
# * The best hyperparameters are min_samples of 7, min_impurity_decrease of 0.0001, max_leaf_nodes of 15, max_depth of 5.

# %%
# to create pipeline with the best parameters
decision_tree_tuned_o = DecisionTreeClassifier( min_samples_leaf = 7, 
                                             min_impurity_decrease = 0.0001, 
                                             max_leaf_nodes = 15, 
                                             max_depth = 5,
                                             random_state = 1)

# to fit the tuned into the oversampled data
decision_tree_tuned_o.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=5, max_leaf_nodes=15,
#                        min_impurity_decrease=0.0001, min_samples_leaf=7,
#                        random_state=1)

# %% [markdown]
# #### Checking model performance on original data

# %%
decision_tree_tuned_perf_o = model_performance_classification_sklearn(decision_tree_tuned_o, X_train, y_train)
decision_tree_tuned_perf_o
# Out:
#    Accuracy  Recall  Precision    F1
# 0     0.974   0.591      0.904 0.715

# %%
confusion_matrix_sklearn(decision_tree_tuned_o, X_train, y_train)

# %% [markdown]
# #### Observation:
#
# - The Decision tree model with original data has 2.27% False Negatives on the train data which is quite high.

# %% [markdown]
# #### Checking model performance on validation data set

# %%
decision_val_perf_o = model_performance_classification_sklearn(decision_tree_tuned_o, X_val, y_val)
decision_val_perf_o
# Out:
#    Accuracy  Recall  Precision    F1
# 0     0.970   0.583      0.822 0.682

# %%
confusion_matrix_sklearn(decision_tree_tuned_o, X_val, y_val)

# %% [markdown]
# #### Observation:
#
# * The model has a low recall score.
#
# * The Decision Tree model with original data has 2.32% False Negatives which is quite high.

# %% [markdown]
# ### Sample tuning method for Decision tree with oversampled data

# %%
# %%time 

# defining model
Model = DecisionTreeClassifier(random_state=1)

# Parameter grid to pass in RandomSearchCV
param_grid = {'max_depth': np.arange(2,6),
              'min_samples_leaf': [1, 4, 7], 
              'max_leaf_nodes' : [10,15],
              'min_impurity_decrease': [0.0001,0.001] }

#Calling RandomizedSearchCV
randomized_cv = RandomizedSearchCV(estimator=Model, param_distributions=param_grid, n_iter=10, n_jobs = -1, scoring=scorer, cv=5, random_state=1)

#Fitting parameters in RandomizedSearchCV
randomized_cv.fit(X_train_over,y_train_over)

print("Best parameters are {} with CV score={}:" .format(randomized_cv.best_params_,randomized_cv.best_score_))
# Out:
# Best parameters are {'min_samples_leaf': 7, 'min_impurity_decrease': 0.001, 'max_leaf_nodes': 15, 'max_depth': 3} with CV score=0.9102913265648006:
# Wall time: 15.6 s

# %% [markdown]
# #### Observation:
#
# * The best Cross validation score using the recall score is around 91% on the training set.
#
# * The best hyperparameters are min_samples_leaf of 7, mn_impurity_decrease of 0.001, max_leaf_nodes of 15, max_depth of 3.

# %%
# to create pipeline with the best parameters
decision_tree_tuned = DecisionTreeClassifier( min_samples_leaf = 7, 
                                             min_impurity_decrease = 0.001, 
                                             max_leaf_nodes = 15, 
                                             max_depth = 3,
                                             random_state = 1)

# to fit the tuned into the oversampled data
decision_tree_tuned.fit(X_train_over, y_train_over)
# Out:
# DecisionTreeClassifier(max_depth=3, max_leaf_nodes=15,
#                        min_impurity_decrease=0.001, min_samples_leaf=7,
#                        random_state=1)

# %% [markdown]
# #### Checking model performance on oversampled data

# %%
decision_tree_tuned_perf = model_performance_classification_sklearn(decision_tree_tuned, X_train_over, y_train_over)
decision_tree_tuned_perf
# Out:
#    Accuracy  Recall  Precision    F1
# 0     0.843   0.917      0.799 0.854

# %%
confusion_matrix_sklearn(decision_tree_tuned, X_train_over, y_train_over)

# %% [markdown]
# #### Checking model performance on validation data set

# %%
decision_val_perf = model_performance_classification_sklearn(decision_tree_tuned, X_val, y_val)
decision_val_perf
# Out:
#    Accuracy  Recall  Precision    F1
# 0     0.763   0.885      0.176 0.294

# %%
confusion_matrix_sklearn(decision_tree_tuned, X_val, y_val)

# %% [markdown]
# #### Observation:
# * The model has a good recall score but a low precision at 17%.
#
# * The model has false negatives of 0.64% but false positives of 23.04%.

# %% [markdown]
# ### Sample tuning method for Decision tree with undersampled data

# %%
# %%time 

# defining model
Model = DecisionTreeClassifier(random_state=1)

# Parameter grid to pass in RandomSearchCV
param_grid = {'max_depth': np.arange(2,20),
              'min_samples_leaf': [1, 2, 5, 7], 
              'max_leaf_nodes' : [5, 10,15],
              'min_impurity_decrease': [0.0001,0.001] }

#Calling RandomizedSearchCV
randomized_cv = RandomizedSearchCV(estimator=Model, param_distributions=param_grid, n_iter=10, n_jobs = -1, scoring=scorer, cv=5, random_state=1)

#Fitting parameters in RandomizedSearchCV
randomized_cv.fit(X_train_un,y_train_un)

print("Best parameters are {} with CV score={}:" .format(randomized_cv.best_params_,randomized_cv.best_score_))
# Out:
# Best parameters are {'min_samples_leaf': 1, 'min_impurity_decrease': 0.001, 'max_leaf_nodes': 5, 'max_depth': 2} with CV score=0.850811629752543:
# Wall time: 1.05 s

# %% [markdown]
# #### Observation:
#
# * The best cross validation using the recall score is around 85% on the training set.
#
# * The best hyperparameters are min_samples_leaf of 1, min_impurity_decrease of 0.001, max_leaf_nodes of 5 and max_depth of 2.

# %%
# to create pipeline with the best parameters
decision_tree_tuned_u = DecisionTreeClassifier( min_samples_leaf = 1, 
                                             min_impurity_decrease = 0.001, 
                                             max_leaf_nodes = 5, 
                                             max_depth = 2,
                                             random_state = 1)

# to fit the tuned into the oversampled data
decision_tree_tuned_u.fit(X_train_un, y_train_un)
# Out:
# DecisionTreeClassifier(max_depth=2, max_leaf_nodes=5,
#                        min_impurity_decrease=0.001, random_state=1)

# %% [markdown]
# #### Checking model performance on undersampled data

# %%
decision_tree_tuned_perf_u = model_performance_classification_sklearn(decision_tree_tuned_u, X_train_un, y_train_un)
decision_tree_tuned_perf_u
# Out:
#    Accuracy  Recall  Precision    F1
# 0     0.764   0.909      0.705 0.794

# %%
confusion_matrix_sklearn(decision_tree_tuned_u, X_train, y_train)

# %% [markdown]
# #### Observation:
#
# * The model has false negatives of 0.51% in the training set.

# %% [markdown]
# #### Checking model performance on validation data set

# %%
decision_val_perf_u = model_performance_classification_sklearn(decision_tree_tuned_u, X_val, y_val)
decision_val_perf_u
# Out:
#    Accuracy  Recall  Precision    F1
# 0     0.609   0.888      0.114 0.202

# %%
confusion_matrix_sklearn(decision_tree_tuned_u, X_val, y_val)

# %% [markdown]
# #### Observation:
#
# * The decision tree model has 0.62% False Negatives.
#
# * The False Positives are quite high, over 38.48%

# %% [markdown]
# ### Tuning Random forest using original data

# %%
# %%time 

# defining model
Model = RandomForestClassifier(random_state=1)

# Parameter grid to pass in RandomSearchCV
param_grid = {
    "n_estimators": [200,250,300],
    "min_samples_leaf": np.arange(1, 4),
    "max_features": [np.arange(0.3, 0.6, 0.1),'sqrt'],
    "max_samples": np.arange(0.4, 0.7, 0.1)}

#Calling RandomizedSearchCV
randomized_cv = RandomizedSearchCV(estimator=Model, param_distributions=param_grid, n_iter=50, n_jobs = -1, scoring=scorer, cv=5, random_state=1)

#Fitting parameters in RandomizedSearchCV
randomized_cv.fit(X_train, y_train)

print("Best parameters are {} with CV score={}:" .format(randomized_cv.best_params_,randomized_cv.best_score_))
# Out:
# Best parameters are {'n_estimators': 250, 'min_samples_leaf': 1, 'max_samples': 0.6, 'max_features': 'sqrt'} with CV score=0.6996248466921577:
# Wall time: 15min 22s

# %% [markdown]
# #### Observation:
# * The best cross validation using the recall score is around 69.9% on the training set.
#
# * The best hyperparameters are n_estimators of 250, min_samples_leaf of 1, max_samples of 0.6, max_features value of square root

# %%
# to create pipeline with the best parameters
rf_tuned_o = RandomForestClassifier( min_samples_leaf = 1, 
                                             n_estimators = 250, 
                                             max_samples = 0.6, 
                                             max_features = 'sqrt',
                                             random_state = 1)

# to fit the tuned into the oversampled data
rf_tuned_o.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_features='sqrt', max_samples=0.6, n_estimators=250,
#                        random_state=1)

# %%
confusion_matrix_sklearn(rf_tuned_o, X_train, y_train)

# %% [markdown]
# #### Observation:
#
# * The model has 0.51% of False Negatives on the training set.

# %% [markdown]
# #### Checking model performance on original data

# %%
rf_tuned_perf_o = model_performance_classification_sklearn(rf_tuned_o, X_train, y_train)
rf_tuned_perf_o
# Out:
#    Accuracy  Recall  Precision    F1
# 0     0.995   0.909      1.000 0.952

# %% [markdown]
# #### Checking model performance on validation data set

# %%
rf_val_perf_o = model_performance_classification_sklearn(rf_tuned_o, X_val, y_val)
rf_val_perf_o
# Out:
#    Accuracy  Recall  Precision    F1
# 0     0.983   0.712      0.985 0.827

# %%
confusion_matrix_sklearn(rf_tuned_o, X_val, y_val)

# %% [markdown]
# #### Observation:
#
# * The model has recall of 71% on the validation set.
#
# * The model has 1.60% False Negatives and 0.06% of False Positives.

# %% [markdown]
# ### Tuning Random forest using oversampled data

# %%
# %%time 

# defining model
Model = RandomForestClassifier(random_state=1)

# Parameter grid to pass in RandomSearchCV
param_grid = {
    "n_estimators": [200,250,300],
    "min_samples_leaf": np.arange(1, 4),
    "max_features": [np.arange(0.3, 0.6, 0.1),'sqrt'],
    "max_samples": np.arange(0.4, 0.7, 0.1)}

#Calling RandomizedSearchCV
randomized_cv = RandomizedSearchCV(estimator=Model, param_distributions=param_grid, n_iter=50, n_jobs = -1, scoring=scorer, cv=5, random_state=1)

#Fitting parameters in RandomizedSearchCV
randomized_cv.fit(X_train_over, y_train_over)

print("Best parameters are {} with CV score={}:" .format(randomized_cv.best_params_,randomized_cv.best_score_))
# Out:
# Best parameters are {'n_estimators': 200, 'min_samples_leaf': 1, 'max_samples': 0.6, 'max_features': 'sqrt'} with CV score=0.9818606498020482:
# Wall time: 24min 53s

# %% [markdown]
# #### Observation:
#
# * The best Cross validation score on the oversampled data is about 98%.
#
# * The best parameters are number of estimators at 200, minimum samples leaf at 1, maximum samples at 0.6 and maximum features as a square root.

# %%
# to create pipeline with the best parameters
rf_tuned = RandomForestClassifier( min_samples_leaf = 1, 
                                             n_estimators = 200, 
                                             max_samples = 0.6, 
                                             max_features = 'sqrt',
                                             random_state = 1)

# to fit the tuned into the oversampled data
rf_tuned.fit(X_train_over, y_train_over)
# Out:
# RandomForestClassifier(max_features='sqrt', max_samples=0.6, n_estimators=200,
#                        random_state=1)

# %% [markdown]
# #### Checking model performance on oversampled data

# %%
rf_tuned_perf = model_performance_classification_sklearn(rf_tuned, X_train_over, y_train_over)
rf_tuned_perf
# Out:
#    Accuracy  Recall  Precision    F1
# 0     1.000   0.999      1.000 1.000

# %%
confusion_matrix_sklearn(rf_tuned, X_train_over, y_train_over)

# %% [markdown]
# #### Observation:
#
# * The model has 0.03% False Negatives and the recall score is close to 100%.

# %% [markdown]
# #### Checking model performance on validation data set

# %%
rf_val_perf = model_performance_classification_sklearn(rf_tuned, X_val, y_val)
rf_val_perf
# Out:
#    Accuracy  Recall  Precision    F1
# 0     0.988   0.863      0.920 0.891

# %%
confusion_matrix_sklearn(rf_tuned, X_val, y_val)

# %% [markdown]
# #### Observation:
#
# * The model is performing well as it gives a good recall score of 86%.
#
# * The model has 0.76% False Negatives and 0.42% False Positives in the validation set.
#
# * The RandomForest model with oversampling technique has produced a good prediction on the validation set.

# %% [markdown]
# ### Tuning Random forest using undersampled data

# %%
# %%time 

# defining model
Model = RandomForestClassifier(random_state=1)

# Parameter grid to pass in RandomSearchCV
param_grid = {
    "n_estimators": [200,250,300],
    "min_samples_leaf": np.arange(1, 4),
    "max_features": [np.arange(0.3, 0.6, 0.1),'sqrt'],
    "max_samples": np.arange(0.4, 0.7, 0.1)}

#Calling RandomizedSearchCV
randomized_cv = RandomizedSearchCV(estimator=Model, param_distributions=param_grid, n_iter=50, n_jobs = -1, scoring=scorer, cv=5, random_state=1)

#Fitting parameters in RandomizedSearchCV
randomized_cv.fit(X_train_un, y_train_un)

print("Best parameters are {} with CV score={}:" .format(randomized_cv.best_params_,randomized_cv.best_score_))
# Out:
# Best parameters are {'n_estimators': 300, 'min_samples_leaf': 2, 'max_samples': 0.5, 'max_features': 'sqrt'} with CV score=0.8990116153235697:
# Wall time: 1min 32s

# %% [markdown]
# #### Observation:
#
# * The best Cross validation score is at 89%.
#
# * The best parameters are number of estimators at 300, minimum samples leaf at 2, maximum samples at 0.5, maximum features as a square root.

# %%
# to create pipeline with the best parameters
rf_tuned_under = RandomForestClassifier( min_samples_leaf = 2, 
                                             n_estimators = 300, 
                                             max_samples = 0.5, 
                                             max_features = 'sqrt',
                                             random_state = 1)

# to fit the tuned into the oversampled data
rf_tuned_under.fit(X_train_un, y_train_un)
# Out:
# RandomForestClassifier(max_features='sqrt', max_samples=0.5, min_samples_leaf=2,
#                        n_estimators=300, random_state=1)

# %% [markdown]
# #### Checking model performance on undersampled data

# %%
rf_tuned_perf1 = model_performance_classification_sklearn(rf_tuned_under, X_train_un, y_train_un)
rf_tuned_perf1
# Out:
#    Accuracy  Recall  Precision    F1
# 0     0.961   0.933      0.989 0.960

# %%
confusion_matrix_sklearn(rf_tuned_under, X_train_un, y_train_un)

# %% [markdown]
# #### Observation:
#
# * The model has 3.37% of False Negatives on the training set which is quite high.

# %% [markdown]
# #### Checking model performance on validation data set

# %%
rf_val_perf1 = model_performance_classification_sklearn(rf_tuned_under, X_val, y_val)
rf_val_perf1
# Out:
#    Accuracy  Recall  Precision    F1
# 0     0.938   0.885      0.468 0.612

# %%
confusion_matrix_sklearn(rf_tuned_under, X_val, y_val)

# %% [markdown]
# #### Observation:
#
# * The model is giving a good recall score but a low precision score.
#
# * The model has 0.64% False Negatives which is high compared to the RandomForest with oversampled data.

# %% [markdown]
# ### Tuning AdaBoost using oversampled data

# %%
# %%time 

# defining model
Model = AdaBoostClassifier(random_state=1)

# Parameter grid to pass in RandomSearchCV
param_grid = {
    "n_estimators": [100, 150, 200],
    "learning_rate": [0.2, 0.05],
    "base_estimator": [DecisionTreeClassifier(max_depth=1, random_state=1), DecisionTreeClassifier(max_depth=2, random_state=1), DecisionTreeClassifier(max_depth=3, random_state=1),
    ]
}


#Calling RandomizedSearchCV
randomized_cv = RandomizedSearchCV(estimator=Model, param_distributions=param_grid, n_iter=50, n_jobs = -1, scoring=scorer, cv=5, random_state=1)

#Fitting parameters in RandomizedSearchCV
randomized_cv.fit(X_train_over,y_train_over) ## Complete the code to fit the model on over sampled data

print("Best parameters are {} with CV score={}:" .format(randomized_cv.best_params_,randomized_cv.best_score_))
# Out:
# Best parameters are {'n_estimators': 200, 'learning_rate': 0.2, 'base_estimator': DecisionTreeClassifier(max_depth=3, random_state=1)} with CV score=0.9715559462639259:
# Wall time: 37min 43s

# %% [markdown]
# #### Observation:
#
# * The best Cross validation score is at 97%.
#
# * The best parameters are number of estimators at 200, learning rate at 0.2, base estimator as DecisionTreeClassifier with max_depth at 3

# %%
# Creating new pipeline with best parameters
tuned_ada = AdaBoostClassifier(
    n_estimators= 200, learning_rate= 0.2, base_estimator= DecisionTreeClassifier(max_depth= 3, random_state=1))

# to fit the model on oversampled data
tuned_ada.fit(X_train_over, y_train_over)
# Out:
# AdaBoostClassifier(base_estimator=DecisionTreeClassifier(max_depth=3,
#                                                          random_state=1),
#                    learning_rate=0.2, n_estimators=200)

# %% [markdown]
# #### Checking model performance on oversampled data

# %%
ada_train_perf = model_performance_classification_sklearn(tuned_ada, X_train_over, y_train_over)
ada_train_perf
# Out:
#    Accuracy  Recall  Precision    F1
# 0     0.992   0.988      0.995 0.992

# %%
confusion_matrix_sklearn(tuned_ada, X_train_over, y_train_over)

# %% [markdown]
# #### Observation
#
# * The model has 0.59% of False Negatives and a recall of 98% on the training set

# %% [markdown]
# #### Checking model performance on validation data set

# %%
ada_val_perf = model_performance_classification_sklearn(tuned_ada, X_val, y_val)
ada_val_perf
# Out:
#    Accuracy  Recall  Precision    F1
# 0     0.979   0.853      0.790 0.820

# %%
confusion_matrix_sklearn(tuned_ada, X_val, y_val)

# %% [markdown]
# #### Observation:
# * The Recall score is around 85% for this model with 0.41% False Negatives.
#
# * The precision is around 79% which is also good with 1.26% False Positives.

# %% [markdown]
# ### Tuning AdaBoost using undersampled data

# %%
# %%time 

# defining model
Model = AdaBoostClassifier(random_state=1)

# Parameter grid to pass in RandomSearchCV
param_grid = {
    "n_estimators": [100, 150, 200],
    "learning_rate": [0.2, 0.05],
    "base_estimator": [DecisionTreeClassifier(max_depth=1, random_state=1), DecisionTreeClassifier(max_depth=2, random_state=1), DecisionTreeClassifier(max_depth=3, random_state=1),
    ]
}


#Calling RandomizedSearchCV
randomized_cv = RandomizedSearchCV(estimator=Model, param_distributions=param_grid, n_iter=50, n_jobs = -1, scoring=scorer, cv=5, random_state=1)

#Fitting parameters in RandomizedSearchCV
randomized_cv.fit(X_train_un,y_train_un) ## Complete the code to fit the model on over sampled data

print("Best parameters are {} with CV score={}:" .format(randomized_cv.best_params_,randomized_cv.best_score_))
# Out:
# Best parameters are {'n_estimators': 200, 'learning_rate': 0.05, 'base_estimator': DecisionTreeClassifier(max_depth=2, random_state=1)} with CV score=0.8906283817906356:
# Wall time: 2min 15s

# %% [markdown]
# #### Observation:
#
# * The best Cross validation score is at 89%.
#
# * The best parameters are number of estimators at 200, learning rate at 0.05, base estimator as DecisionTreeClassifier with max_depth at 2

# %%
# Creating new pipeline with best parameters
tuned_ada1 = AdaBoostClassifier(
    n_estimators= 200, learning_rate= 0.05, base_estimator= DecisionTreeClassifier(max_depth= 2, random_state=1))

# to fit the model on oversampled data
tuned_ada1.fit(X_train_un, y_train_un)
# Out:
# AdaBoostClassifier(base_estimator=DecisionTreeClassifier(max_depth=2,
#                                                          random_state=1),
#                    learning_rate=0.05, n_estimators=200)

# %% [markdown]
# #### Checking model performance on undersampled data

# %%
ada_train_perf1 = model_performance_classification_sklearn(tuned_ada1, X_train_un, y_train_un)
ada_train_perf1
# Out:
#    Accuracy  Recall  Precision    F1
# 0     0.950   0.916      0.982 0.948

# %%
confusion_matrix_sklearn(tuned_ada1, X_train_un, y_train_un)

# %% [markdown]
# #### Observation
#
# * The model has 4.21% False Negatives which is quite high.

# %% [markdown]
# #### Checking model performance on validation data set

# %%
ada_val_perf1 = model_performance_classification_sklearn(tuned_ada1, X_val, y_val)
ada_val_perf1
# Out:
#    Accuracy  Recall  Precision    F1
# 0     0.930   0.874      0.435 0.581

# %%
confusion_matrix_sklearn(tuned_ada1, X_val, y_val)

# %% [markdown]
# #### Observation:
#
# * The model has a high recall score of 88% with 0.70% of False Negatives.

# %% [markdown]
# ### Tuning Gradient Boosting using oversampled data

# %%
# %%time 

# defining model
Model = GradientBoostingClassifier(random_state=1)

#Parameter grid to pass in RandomSearchCV
param_grid={"n_estimators": np.arange(100,150,25), 
            "learning_rate": [0.2, 0.05, 1], "subsample":[0.5,0.7], "max_features":[0.5,0.7]}

#Calling RandomizedSearchCV
randomized_cv = RandomizedSearchCV(estimator=Model, param_distributions=param_grid, scoring=scorer, n_iter=50, n_jobs = -1, cv=5, random_state=1)

#Fitting parameters in RandomizedSearchCV
randomized_cv.fit(X_train_over, y_train_over)

print("Best parameters are {} with CV score={}:" .format(randomized_cv.best_params_,randomized_cv.best_score_))
# Out:
# Best parameters are {'subsample': 0.7, 'n_estimators': 125, 'max_features': 0.5, 'learning_rate': 1} with CV score=0.9726145954486902:
# Wall time: 15min 16s

# %% [markdown]
# #### Observation:
#
# * The best Cross validation score is at 97%.
#
# * The best parameters are number of estimators at 125, learning rate at 1, subsample at 0.7 and max_features of 0.5

# %%
# Creating new pipeline with best parameters
tuned_gbm = GradientBoostingClassifier(
    max_features= 0.5,
    random_state= 1,
    learning_rate= 1,
    n_estimators= 125,
    subsample= 0.7,
)

# best parameters obtained from tuning

tuned_gbm.fit(X_train_over, y_train_over)
# Out:
# GradientBoostingClassifier(learning_rate=1, max_features=0.5, n_estimators=125,
#                            random_state=1, subsample=0.7)

# %% [markdown]
# #### Checking model performance on oversampled data

# %%
gbm_train_perf = model_performance_classification_sklearn(
    tuned_gbm, X_train_over, y_train_over
)
gbm_train_perf
# Out:
#    Accuracy  Recall  Precision    F1
# 0     0.993   0.993      0.994 0.993

# %%
confusion_matrix_sklearn(tuned_gbm, X_train_over, y_train_over)

# %% [markdown]
# #### Observation:
#
# * The model has 0.36% of False negatives and 0.32% False Positives in the training set.

# %% [markdown]
# #### Checking model performance on validation data set

# %%
gbm_val_perf = model_performance_classification_sklearn(
    tuned_gbm, X_val, y_val
)
gbm_val_perf
# Out:
#    Accuracy  Recall  Precision    F1
# 0     0.970   0.842      0.692 0.760

# %%
confusion_matrix_sklearn(tuned_gbm, X_val, y_val)

# %% [markdown]
# #### Observation:
# * The recall score of the model is at 84% with 0.88% of False Negatives.
#
# * The precision score of the model is 69% with 2.08% of False Positives.

# %% [markdown]
# ### Tuning XGBoost using oversampled data

# %%
from xgboost import XGBClassifier

# to suppress scientific notations for a dataframe
pd.set_option("display.float_format", lambda x: "%.3f" % x)

# %%
# %%time 

# defining model
Model = XGBClassifier(random_state=1, eval_metric='logloss')

#Parameter grid to pass in RandomSearchCV
param_grid={'n_estimators':[150,200,250],'scale_pos_weight':[5,10], 
            'learning_rate':[0.1,0.2], 'gamma':[0,3,5], 'subsample':[0.8,0.9]}

#Calling RandomizedSearchCV
randomized_cv = RandomizedSearchCV(estimator=Model, param_distributions=param_grid, n_iter=50, n_jobs = -1, scoring=scorer, cv=5, random_state=1)

#Fitting parameters in RandomizedSearchCV
randomized_cv.fit(X_train_over, y_train_over) # code to fit the model on over sampled data

print("Best parameters are {} with CV score={}:" .format(randomized_cv.best_params_,randomized_cv.best_score_))
# Out:
# Best parameters are {'subsample': 0.8, 'scale_pos_weight': 10, 'n_estimators': 250, 'learning_rate': 0.2, 'gamma': 0} with CV score=0.995765154155294:
# Wall time: 2h 49min 31s

# %% [markdown]
# #### Observation:
# * The best Cross validation score is at 99%.
#
# * The best parameters are number of estimators at 250, learning rate at 0.2, subsample at 0.8, scale position weight at 10 and gamma at 0.

# %%
# the best parameters obtained from tuning 
xgb2 = XGBClassifier(
    random_state=1,
    eval_metric="logloss",
    subsample= 0.8,
    scale_pos_weight= 10,
    n_estimators= 250,
    learning_rate= 0.2,
    gamma= 0,
)

# to fit the model on the oversampled data

xgb2.fit(X_train_over, y_train_over)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#               eval_metric='logloss', gamma=0, gpu_id=-1, importance_type=None,
#               interaction_constraints='', learning_rate=0.2, max_delta_step=0,
#               max_depth=6, min_child_weight=1, missing=nan,
#               monotone_constraints='()', n_estimators=250, n_jobs=4,
#               num_parallel_tree=1, predictor='auto', random_state=1,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=10, subsample=0.8,
#               tree_method='exact', validate_parameters=1, verbosity=None)

# %% [markdown]
# #### Checking model performance on oversampled data

# %%
xgb2_train_perf = model_performance_classification_sklearn(
    xgb2, X_train_over, y_train_over
)
xgb2_train_perf
# Out:
#    Accuracy  Recall  Precision    F1
# 0     1.000   1.000      1.000 1.000

# %%
confusion_matrix_sklearn(xgb2, X_train_over, y_train_over)

# %% [markdown]
# #### Observation:
#
# * From the confusion matrix above, the model produced a recall of 100%.
#
# * It also gave a precsion score of 100%.

# %% [markdown]
# #### Checking model performance on validaton data

# %%
xgb2_val_perf = model_performance_classification_sklearn(
    xgb2, X_val, y_val)
xgb2_val_perf
# Out:
#    Accuracy  Recall  Precision    F1
# 0     0.986   0.878      0.878 0.878

# %%
confusion_matrix_sklearn(xgb2, X_val, y_val)

# %% [markdown]
# #### Observation:
#
# * The model produced 0.68% both on the False Negatives and False Positives. The model is performing well on the validation set compared to the other models.
#
# * The recall score is 87.8% and the precision score is at 87.8%.

# %% [markdown]
# ## Model performance comparison and choosing the final model

# %%
# training performance comparison

models_train_comp_df = pd.concat(
    [
        decision_tree_tuned_perf_o.T,
        decision_tree_tuned_perf.T,
        decision_tree_tuned_perf_u.T,
        rf_tuned_perf_o.T,
        rf_tuned_perf.T,
        rf_tuned_perf1.T,
        ada_train_perf.T,
        ada_train_perf1.T,
        gbm_train_perf.T,
        xgb2_train_perf.T,
    ],
    axis=1,
)
models_train_comp_df.columns = [
    "Decision Tree tuned with original data",
    "Decision Tree tuned with oversampled data",
    "Decision Tree tuned with undersampled data",
    "Random forest tuned with original data",
    "Random forest tuned with oversampled data",
    "Random forest tuned with undersampled data",
    "AdaBoost classifier tuned with oversampled data",
    "AdaBoost Classifier tuned with undersampled data",
    "Gradient Boosting tuned with oversampled data",
    "XGBoost tuned with oversampled data",
]
print("Training performance comparison:")
models_train_comp_df
# Out:
# Training performance comparison:
#            Decision Tree tuned with original data  \
# Accuracy                                    0.974
# Recall                                      0.591
# Precision                                   0.904
# F1                                          0.715
#
#            Decision Tree tuned with oversampled data  \
# Accuracy                                       0.843
# Recall                                         0.917
# Precision                                      0.799
# F1                                             0.854
#
#            Decision Tree tuned with undersampled data  \
# Accuracy                                        0.764
# Recall                                          0.909
# Precision                                       0.705
# F1                                              0.794
#
#            Random forest tuned with original data  \
# Accuracy                                    0.995
# ...

# %% [markdown]
# #### Observation:
#
# * The XGBoost tuned model with oversampled data and the Random Forest tuned with oversampled data had the highest score on recall and precision.

# %%
# Validation performance comparison

models_train_comp_df = pd.concat(
    [
        decision_val_perf_o.T,
        decision_val_perf.T,
        decision_val_perf_u.T,
        rf_val_perf_o.T,
        rf_val_perf.T,
        rf_val_perf1.T,
        ada_val_perf.T,
        ada_val_perf1.T,
        gbm_val_perf.T,
        xgb2_val_perf.T,
    ],
    axis=1,
)
models_train_comp_df.columns = [
    "Decision Tree tuned with original data",
    "Decision Tree tuned with oversampled data",
    "Decision Tree tuned with undersampled data",
    "Random forest tuned with original data",
    "Random forest tuned with oversampled data",
    "Random forest tuned with undersampled data",
    "AdaBoost classifier tuned with oversampled data",
    "AdaBoost Classifier tuned with undersampled data",
    "Gradient Boosting tuned with oversampled data",
    "XGBoost tuned with oversampled data",
]
print("Validation performance comparison:")
models_train_comp_df
# Out:
# Validation performance comparison:
#            Decision Tree tuned with original data  \
# Accuracy                                    0.970
# Recall                                      0.583
# Precision                                   0.822
# F1                                          0.682
#
#            Decision Tree tuned with oversampled data  \
# Accuracy                                       0.763
# Recall                                         0.885
# Precision                                      0.176
# F1                                             0.294
#
#            Decision Tree tuned with undersampled data  \
# Accuracy                                        0.609
# Recall                                          0.888
# Precision                                       0.114
# F1                                              0.202
#
#            Random forest tuned with original data  \
# Accuracy                                    0.983
# ...

# %% [markdown]
# #### Observation:
#
# * The XGBoost tuned with oversampled data gives a good recall score (87.8%) and also a good precision score (87.8%) compared to the RandomForest model with undersampled data (88.5%) recall score and (46.8%) precision score.
#
# * The XGBoost model is chosen as the best model because it performs well on all metric forms. It is chosen ahead of the RandomForest model with undersampled data because the latter has low precision score and most of the information of data points has been removed using the RandomSampling Technique.
#
# * The Business problem needs a minimized recall score and precision score. XGBoost model will fit in well. Let's check the performance on the test set.

# %% [markdown]
# ### Test set final performance

# %%
# Let's check the performance on test set
xgb2_test_perf = model_performance_classification_sklearn(
    xgb2, X_test, y_test
)
xgb2_test_perf
# Out:
#    Accuracy  Recall  Precision    F1
# 0     0.982   0.848      0.842 0.845

# %%
confusion_matrix_sklearn(xgb2, X_test, y_test)

# %% [markdown]
# #### Observation:
#
# * The XGBoost Classifier model with oversampled data is performing well on the test data.
#
# * The recall is at 84.8% and 84.2% precision score which shows it is not overfitting.
#
# * The False Negatives is at 0.86% and the False Positives is at 0.90%.

# %% [markdown]
# ### Feature Importance of XGBoost Classfier model with oversampled data

# %%
feature_names = X_train_over.columns
importances = xgb2.feature_importances_  # to check the feature importance of the best model
indices = np.argsort(importances)

plt.figure(figsize=(12, 12))
plt.title("Feature Importances")
plt.barh(range(len(indices)), importances[indices], color="violet", align="center")
plt.yticks(range(len(indices)), [feature_names[i] for i in indices])
plt.xlabel("Relative Importance")
plt.show()

# %% [markdown]
# #### Observation:
#
# * From the feature importance of the XGBoost Classifier model with oversammpled data, the most important that determines whether  a generator fails or not is the ciphered data from sensor V36. It could be an environmental feature or component feature of the wind turbine.
#
# * The other top 6 ciphered data from the sensors to look out for to identify failures of generator are V14, V24, V16, V18, V1 and V21.
#
# * The other ciphered data from sensors have almost the same likelihood to identify failures of generator.

# %% [markdown]
# ## Pipelines to build the final model

# %%
# Creating new pipeline with best parameters
model = Pipeline(
    steps=[
        ( "imputer", SimpleImputer(strategy="median")),
        (
            "XGB",
             XGBClassifier(
             random_state=1,
             eval_metric="logloss",
             subsample= 0.8,
             scale_pos_weight= 10,
             n_estimators= 250,
             learning_rate= 0.2,
             gamma= 0,
            ),
        ),
    ]
)

# %%
# Separating target variable and other variables
X1 = data.drop(columns="Target")
Y1 = data["Target"]


X_test1 = df1.drop(columns= "Target")
y_test1 = df1["Target"]

# %%
# to treat the missing values in the train set
imputer = SimpleImputer(strategy="median")
X1 = imputer.fit_transform(X1)

# %%
# Synthetic Minority Over Sampling Technique
sm = SMOTE(sampling_strategy=1, k_neighbors=5, random_state=1)
X_over1, y_over1 = sm.fit_resample(X1, Y1)

# %%
# Fit the model on training data
model.fit(X_over1, y_over1)
# Out:
# Pipeline(steps=[('imputer', SimpleImputer(strategy='median')),
#                 ('XGB',
#                  XGBClassifier(base_score=0.5, booster='gbtree',
#                                colsample_bylevel=1, colsample_bynode=1,
#                                colsample_bytree=1, enable_categorical=False,
#                                eval_metric='logloss', gamma=0, gpu_id=-1,
#                                importance_type=None, interaction_constraints='',
#                                learning_rate=0.2, max_delta_step=0, max_depth=6,
#                                min_child_weight=1, missing=nan,
#                                monotone_constraints='()', n_estimators=250,
#                                n_jobs=4, num_parallel_tree=1, predictor='auto',
#                                random_state=1, reg_alpha=0, reg_lambda=1,
#                                scale_pos_weight=10, subsample=0.8,
# ...

# %%
# Let's check the performance on test set
Model_test = model_performance_classification_sklearn(model, X_test1, y_test1)
Model_test
# Out:
#    Accuracy  Recall  Precision    F1
# 0     0.983   0.851      0.851 0.851

# %%
confusion_matrix_sklearn(model, X_test1, y_test1)

# %% [markdown]
# #### Observation:
#
# - A pipeline is built using the XGBoost Classifier model and also a median imputer is put in place to treat missing values.
#
# - The model is performing well on the test set giving a high recall of 85% and 85% precision score.
#
# - The confusion matrix shows the False negatives are at 0.84% and the False Positives are 0.84%.

# %% [markdown]
# # Business Insights and Conclusions

# %% [markdown]
# #### Business Insights:
#
#  Generators are one of the most critical components in a wind turbine. Any issues with this hardware will decrease operational availability. The following are the insights gained from the predictive maintenance analysis:
#
# * `Intelligent Control`: The model has helped to provide greater visibility and control that can predict if a generator has failed or not using the data from the sensors.
#
# * The sensor(ciphered version V36) fitted on a component is important to determine whether a generator fails or not.
# * The top 10 sensors fitted on a component that determines whether a generator fails or not are:
#
# * V14,
#   V24,
#   V16,
#   V18,
#   V1,
#   V21.
#
#   The remaining sensors(ciphered version have almost the likelihood of determining whether a generator fails or not.
#
#   The sensors(ciphered version) could represent environmental factors and additional features of the wind turbine.
#
# * `Real time Control`: The availability of a computer software than can process the information of the sensor (ciphered version) should be deployed with the XGBoost model. This will help in tackling the early response to the components and environmental factors of the machine that might cause the wind turbine to fail.
#
# * `Reliability`:  The model produced a good prediction on machines that fails. This will help to reduce repair costs.
#
# * The instance where there are real failures of the machine but the model did not detect was minimized. This will reduce false alarms and replacement costs for Renewind.
#
# * The instance where there are no failures of the generator but the model detected as failure was also minimized. The model made good predictions on this instance and will help to reduce inspection cost for Renewind.
#
# * `Reduce Cost`: The model prediction could held reduce logistics and material costs, as well as potential downtime.
#
# * The sensors has helped receive single point operational reporting on different parameters ranging from temperature to generator inspection that can help in predictive analysis using the XGBoost Classifier model.
#
# * `Cost Efficiency`: All of the use cases described above pursue one ultimate goal – reduce the operational and maintenance costs through improved predictive performance by using the XGBoost Classifier model.

# %% [markdown]
# ### Business Recommendations:
#
# * Condition monitoring: Renewind can implement a Condition-based maintenance strategy using the XGBoost model whereby the condition of the generator is actively monitored to detect impending or incipient faults, allowing an effective maintenance decision to be made as needed.
#
# * This strategy can save up to 20-25% of maintenance costs compared to scheduled maintenance of wind turbines.
#
# * Condition based maintenance strategy can also allow prognostic analysis, whereby the remaining useful life of a component is estimated. This can allow even more granular planning for maintenance actions.
#
# * Renewind can solve failures of generator after it has been processed by the model, using the operation manuals to solve such faults. This will help minimize downtime of the wind turbines.
#
# * Renewind could consider further improvement for the prediction of a specific fault one hour in advance. This will help improve the prediction and help to save maintenance costs. It can also generate revenue for the company.

# %% [markdown]
# ### Conclusions:
#
# - Different Classification model for predicting turbine faults based on ciphered data was built to analyze if a generator  will fail or not.
#
# -  Overall less ideal performance could be due to the highly imbalanced nature of failure data, with the no-failure class having an overwhelming majority of samples. The application of Simple Minority Oversampling technique was applied to balance the target variable.
#
# - The XGBoost model with oversampled data had a good performance on both the recall score and precision score.
#
# - The XGBoost model will enable the following benefits:
#
#   * Improved planning of predictive and corrective maintenance improving repair costs.
#   * Minimized on-site visits will reduce inspection costs.
#   * Reduced replacement costs.
#
# -  Connected sensors, coupled with predictive analytics model(XGBoost Classifier), have emerged as strong contenders to maximize reliability and performance. At the end of the day, ReneWind with qualitative data will be leading the predictive maintenance wave and realizing the benefits outlined above.
